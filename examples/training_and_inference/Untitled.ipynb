# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://aqueduct:aqueduct@pg-db1.chp4ztvsitj1.us-east-2.rds.amazonaws.com:5432/postgres')

# %%
import pandas as pd
df = pd.read_csv('~/wines.csv', index_col='id')
df
# Out:
#       color  fixed_acidity  volatile_acidity  citric_acid residual_sugar  \
# id
# 0     white            7.0              0.17         0.74             \N
# 1       red            7.7              0.64         0.21            2.2
# 2     white            6.8              0.39         0.34            7.4
# 3     white            6.3              0.28         0.47             \N
# 4     white            7.4              0.35         0.20           13.9
# ...     ...            ...               ...          ...            ...
# 6492  white            7.6              0.32         0.58          16.75
# 6493  white            5.6              0.28         0.27            3.9
# 6494  white            6.4              0.37         0.20            5.6
# 6495  white            6.5              0.26         0.50            8.0
# 6496    red            7.2              0.62         0.06            2.7
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# id
# ...

# %%
df.to_sql(con=engine, index_label='id', name='wine')
# Out:
# 497
