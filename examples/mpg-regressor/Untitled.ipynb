# %%
import pandas as pd

pd.read_json('/Users/vikram/.aqueduct/server/storage/d2c769c3-3c98-4959-a845-91eff5dc4546', orient="table")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-7-8b5007a14cad> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_json('/Users/vikram/.aqueduct/server/storage/d2c769c3-3c98-4959-a845-91eff5dc4546', orient="table")
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
