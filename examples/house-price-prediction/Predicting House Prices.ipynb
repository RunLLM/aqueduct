# %%
import pandas as pd
df = pd.read_csv(
    'diabetes.csv', 
    names=[
        'pregnancies', 
        'glucose', 
        'diastolic_bp', 
        'triceps_skin_fold',
        '2_hr_insulin',
        'bmi',
        'pedigree_fn',
        'age',
        'has_diabetes'
    ],
    header=None
)
df
# Out:
#      pregnancies  glucose  diastolic_bp  triceps_skin_fold  2_hr_insulin  \
# 0              6      148            72                 35             0
# 1              1       85            66                 29             0
# 2              8      183            64                  0             0
# 3              1       89            66                 23            94
# 4              0      137            40                 35           168
# ..           ...      ...           ...                ...           ...
# 763           10      101            76                 48           180
# 764            2      122            70                 27             0
# 765            5      121            72                 23           112
# 766            1      126            60                  0             0
# 767            1       93            70                 31             0
#
#       bmi  pedigree_fn  age  has_diabetes
# 0    33.6        0.627   50             1
# ...

# %%
import aqueduct as aq
import
