# %%
import pandas as pd
import aqueduct
from aqueduct import op, check, metric

# %%
# You can use `localhost` if you're running this notebook on the same machine as the server.
# If you're running your notebook on a separate machine from your
# Aqueduct server, change this to the address of your Aqueduct server.
address = "http://localhost:8080"

# If you're running youre notebook on a separate machine from your
# Aqueduct server, you will have to copy your API key here rather than
# using `get_apikey()`.
api_key = aqueduct.get_apikey()
client = aqueduct.Client(api_key, address)

# %%
demodb = client.integration("sflake")

# %%
wines = demodb.sql("select * from wine;")

# %%
wines.get()
# Out:
#         id  color  fixed_acidity  volatile_acidity  citric_acid  \
# 0        0  white            7.0              0.17         0.74
# 1        1    red            7.7              0.64         0.21
# 2        2  white            6.8              0.39         0.34
# 3        3  white            6.3              0.28         0.47
# 4        4  white            7.4              0.35         0.20
# ...    ...    ...            ...               ...          ...
# 6492  6492  white            7.6              0.32         0.58
# 6493  6493  white            5.6              0.28         0.27
# 6494  6494  white            6.4              0.37         0.20
# 6495  6495  white            6.5              0.26         0.50
# 6496  6496    red            7.2              0.62         0.06
#
#       residual_sugar  chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# 0                NaN      0.045                 24.0                 126.0
# 1               2.20      0.077                 32.0                 133.0
# 2               7.40      0.020                 38.0                 133.0
# 3                NaN      0.040                 61.0                 183.0
# 4              13.90      0.054                 63.0                 229.0
# ...              ...        ...                  ...                   ...
# 6492           16.75      0.050                 43.0                 163.0
# 6493            3.90      0.043                 52.0                 158.0
# 6494            5.60      0.117                 61.0                 183.0
# 6495            8.00      0.051                 46.0                 197.0
# 6496            2.70      0.077                 15.0                  85.0
#
#       density    ph  sulphates  alcohol  quality
# 0     0.99420  3.26       0.38     12.2      8.0
# 1     0.99560  3.27       0.45      9.9      5.0
# 2     0.99212  3.18       0.44     12.0      NaN
# 3     0.99592  3.12       0.51      9.5      6.0
# 4     0.99888  3.11       0.50      8.9      NaN
# ...       ...   ...        ...      ...      ...
# 6492  0.99990  3.15       0.54      9.2      5.0
# 6493  0.99202  3.35       0.44     10.7      7.0
# 6494  0.99459  3.24       0.43      9.5      5.0
# 6495  0.99536  3.18       0.47      9.5      5.0
# 6496  0.99746  3.51       0.54      9.5      5.0
#
# [6497 rows x 14 columns]

# %%
@op
def noop(df):
    return df

# %%
data = noop(wines)

# %%
data.get()
# Out:
#         id  color  fixed_acidity  volatile_acidity  citric_acid  \
# 0        0  white            7.0              0.17         0.74
# 1        1    red            7.7              0.64         0.21
# 2        2  white            6.8              0.39         0.34
# 3        3  white            6.3              0.28         0.47
# 4        4  white            7.4              0.35         0.20
# ...    ...    ...            ...               ...          ...
# 6492  6492  white            7.6              0.32         0.58
# 6493  6493  white            5.6              0.28         0.27
# 6494  6494  white            6.4              0.37         0.20
# 6495  6495  white            6.5              0.26         0.50
# 6496  6496    red            7.2              0.62         0.06
#
#       residual_sugar  chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# 0                NaN      0.045                 24.0                 126.0
# 1               2.20      0.077                 32.0                 133.0
# 2               7.40      0.020                 38.0                 133.0
# 3                NaN      0.040                 61.0                 183.0
# 4              13.90      0.054                 63.0                 229.0
# ...              ...        ...                  ...                   ...
# 6492           16.75      0.050                 43.0                 163.0
# 6493            3.90      0.043                 52.0                 158.0
# 6494            5.60      0.117                 61.0                 183.0
# 6495            8.00      0.051                 46.0                 197.0
# 6496            2.70      0.077                 15.0                  85.0
#
#       density    ph  sulphates  alcohol  quality
# 0     0.99420  3.26       0.38     12.2      8.0
# 1     0.99560  3.27       0.45      9.9      5.0
# 2     0.99212  3.18       0.44     12.0      NaN
# 3     0.99592  3.12       0.51      9.5      6.0
# 4     0.99888  3.11       0.50      8.9      NaN
# ...       ...   ...        ...      ...      ...
# 6492  0.99990  3.15       0.54      9.2      5.0
# 6493  0.99202  3.35       0.44     10.7      7.0
# 6494  0.99459  3.24       0.43      9.5      5.0
# 6495  0.99536  3.18       0.47      9.5      5.0
# 6496  0.99746  3.51       0.54      9.5      5.0
#
# [6497 rows x 14 columns]

# %%
client.publish_flow("testing_airflow", artifacts=[data], engine="my_airflow")
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 client.publish_flow("testing_airflow", artifacts=[data], engine="my_airflow")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/aqueduct/client.py:694, in Client.publish_flow(self, name, description, schedule, engine, artifacts, metrics, checks, k_latest_runs, config, source_flow)
#     684 dag.set_engine_config(
#     685     global_engine_config=generate_engine_config(
#     686         self._connected_integrations,
#    (...)
#     689     publish_flow_engine_config=generate_engine_config(self._connected_integrations, engine),
#     690 )
#     692 if dag.engine_config.type == RuntimeType.AIRFLOW:
#     693     # This is an Airflow workflow
# --> 694     resp = globals.__GLOBAL_API_CLIENT__.register_airflow_workflow(dag)
#     695     flow_id, airflow_file = resp.id, resp.file
#     697     file = "{}_airflow.py".format(name)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/aqueduct/backend/api_client.py:427, in APIClient.register_airflow_workflow(self, dag)
#     425 url = self.construct_full_url(self.REGISTER_AIRFLOW_WORKFLOW_ROUTE, self.use_https)
#     426 resp = requests.post(url, headers=headers, data=body, files=files)
# --> 427 self.raise_errors(resp)
#     429 return RegisterAirflowWorkflowResponse(**resp.json())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/aqueduct/backend/api_client.py:94, in APIClient.raise_errors(self, response)
#      92     raise UnprocessableEntityError(_extract_err_msg())
#      93 elif response.status_code == 500:
# ---> 94     raise InternalServerError(_extract_err_msg())
#      95 elif response.status_code == 404:
#      96     raise ResourceNotFoundError(_extract_err_msg())
#
# InternalServerError: Unexpected error occurred when checking for existing workflows.
